# %% [markdown]
# Importar librerias

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression as LR
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %% [markdown]
# Leer archivo CSV

# %%
df = pd.read_csv("C:/Users/srodr/OneDrive/Documentos/SRB/UniAndes/9no Semestre/Analitica Computacional para la Toma de Decisiones/Proyecto 1/datos_limpios_estos_si_si.csv")

# %% [markdown]
# Grafico de dispersión entre variables

# %%
df
# Out:
#       Rented Bike Count  Hour  Temperature(C)  Humidity(%)  Wind speed (m/s)  \
# 0                   254     0            -5.2           37               2.2
# 1                   204     1            -5.5           38               0.8
# 2                   173     2            -6.0           39               1.0
# 3                   107     3            -6.2           40               0.9
# 4                    78     4            -6.0           36               2.3
# ...                 ...   ...             ...          ...               ...
# 8436               1003    19             4.2           34               2.6
# 8437                764    20             3.4           37               2.3
# 8438                694    21             2.6           39               0.3
# 8439                712    22             2.1           41               1.0
# 8440                584    23             1.9           43               1.3
#
# ...

# %% [markdown]
# Dividir datos de prueba y entrenamiento

# %%
Y=df["Rented Bike Count"]
X=df.drop(["Rented Bike Count"], axis=1)

var=X.corr()
sns.heatmap(var, cmap="Blues", annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Dividir datos de prueba y entrenamiento

# %%
x_train, x_test, y_train, y_test = tts(X,Y,random_state=1, test_size=0.5, shuffle=False)

x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test)

# %% [markdown]
# Crear modelo de regresión lineal

# %%
DemandaBicicletas=sm.OLS(y_train,x_train).fit()

print(DemandaBicicletas.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Rented Bike Count   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     527.8
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):               0.00
# Time:                        20:37:46   Log-Likelihood:                -30268.
# No. Observations:                4220   AIC:                         6.056e+04
# Df Residuals:                    4208   BIC:                         6.064e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                     -272.4691     71.817     -3.794      0.000    -413.269    -131.670
# ...

# %%
X = X.drop(['Summer'], axis=1)

x_train, x_test, y_train, y_test = tts(X,Y,random_state=1, test_size=0.7, shuffle=False)

x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test, has_constant="add")


DemandaBicicleta=sm.OLS(y_train,x_train).fit()
print(DemandaBicicleta.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Rented Bike Count   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     240.5
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):               0.00
# Time:                        20:37:46   Log-Likelihood:                -16500.
# No. Observations:                2532   AIC:                         3.302e+04
# Df Residuals:                    2522   BIC:                         3.308e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hour                         6.9400      0.511     13.582      0.000       5.938       7.942
# ...

# %%
X = X.drop(["Temperature(C)"], axis=1)

x_train, x_test, y_train, y_test = tts(X,Y,random_state=1, test_size=0.7, shuffle=False)

x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test, has_constant="add")


DemandaBicicleta=sm.OLS(y_train,x_train).fit()
print(DemandaBicicleta.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Rented Bike Count   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     270.6
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):               0.00
# Time:                        20:37:46   Log-Likelihood:                -16500.
# No. Observations:                2532   AIC:                         3.302e+04
# Df Residuals:                    2523   BIC:                         3.307e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hour                         6.9218      0.510     13.582      0.000       5.923       7.921
# ...

# %%
X = X.drop(["Wind speed (m/s)"], axis=1)

x_train, x_test, y_train, y_test = tts(X,Y,random_state=1, test_size=0.7, shuffle=False)

x_train=sm.add_constant(x_train)
x_test=sm.add_constant(x_test, has_constant="add")


DemandaBicicleta=sm.OLS(y_train,x_train).fit()
print(DemandaBicicleta.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:      Rented Bike Count   R-squared:                       0.462
# Model:                            OLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     309.3
# Date:                Sun, 08 Sep 2024   Prob (F-statistic):               0.00
# Time:                        20:37:46   Log-Likelihood:                -16500.
# No. Observations:                2532   AIC:                         3.302e+04
# Df Residuals:                    2524   BIC:                         3.306e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Hour                         6.8634      0.498     13.774      0.000       5.886       7.840
# ...

# %% [markdown]
# Calculando metricas

# %%
#y_pred = DemandaBicicleta.predict(x_test)

print (x_test.shape)

#MAE = metrics.mean_absolute_error(y_test, y_pred)
#MSE = metrics.mean_squared_error(y_test, y_pred)
#RMSE = np.sqrt(MSE)
# Out:
# (5909, 10)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.1)
plt.xlabel('Valores Reales')
plt.ylabel('Predicciones')
plt.title('Valores Reales vs. Predicciones')

min_val = 0
max_val = max(max(y_test), max(y_pred))
plt.plot([0, 2500], [0 , 2500], color='red', linestyle='--')

plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.scatter(y_test, y_pred, alpha=0.1)
#       3 plt.xlabel('Valores Reales')
#       4 plt.ylabel('Predicciones')
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# Existe multicolinealidad?

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Añadir constante a X para calcular VIF
X_with_const = sm.add_constant(X)

# Calcular VIF para cada variable
vif_data = pd.DataFrame()
vif_data["Variable"] = X_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i) for i in range(X_with_const.shape[1])]

print(vif_data)
